# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
import matplotlib.pyplot as plt
from glob import glob

train_path = "fruits-360/Training/"
test_path = "fruits-360/Test/"
img = load_img(train_path + "Apple Braeburn/0_100.jpg")
plt.axis("off")
plt.imshow(img)

# %%
x = img_to_array(img)
print(x.shape)
# Out:
# (100, 100, 3)

# %%
className = glob(train_path + "/*")
numberOfClass = len(className)
print("Number of Class: ", numberOfClass)
# Out:
# Number of Class:  131

# %%
##CNN Model
model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape = x.shape))
model.add(Activation("relu"))
model.add(MaxPooling2D())

model.add(Conv2D(32, (3, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D())

model.add(Conv2D(34, (3, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D())

model.add(Flatten())
model.add(Dense(1024))
model.add(Activation("relu"))
model.add(Dropout(0.5))
model.add(Dense(numberOfClass))
model.add(Activation("softmax"))

# %%
model.compile(loss="categorical_crossentropy",
             optimizer = "rmsprop",
             metrics = ["accuracy"])
batch_size = 32

# %%
## Data Generation -Train -Test
train_datagen = ImageDataGenerator(rescale = 1./255,
                  shear_range = 0.3,
                  horizontal_flip = True,
                  zoom_range = 0.3)

test_datagen = ImageDataGenerator(rescale = 1./255)

train_generator = train_datagen.flow_from_directory(train_path, 
                                                    target_size = x.shape[:2],
                                                    batch_size = batch_size,
                                                    color_mode = "rgb",
                                                    class_mode = "categorical")

test_generator = train_datagen.flow_from_directory(test_path, 
                                                    target_size = x.shape[:2],
                                                    batch_size = batch_size,
                                                    color_mode = "rgb",
                                                    class_mode = "categorical")
# Out:
# Found 67692 images belonging to 131 classes.
# Found 22688 images belonging to 131 classes.

# %%
hist = model.fit_generator(generator = train_generator,
                   steps_per_epoch = 1600 // batch_size,
                   epochs = 100,
                   validation_data = test_generator,
                   validation_steps = 800 // batch_size)
# Out:
# WARNING:tensorflow:From <ipython-input-7-7024c9552303>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 50/50 [==============================] - 137s 3s/step - loss: 4.6287 - accuracy: 0.0350 - val_loss: 4.0177 - val_accuracy: 0.1037
# Epoch 2/100
# 50/50 [==============================] - 136s 3s/step - loss: 3.6655 - accuracy: 0.1069 - val_loss: 3.0456 - val_accuracy: 0.1963
# Epoch 3/100
# 50/50 [==============================] - 135s 3s/step - loss: 2.9420 - accuracy: 0.2356 - val_loss: 2.5940 - val_accuracy: 0.2188
# Epoch 4/100
# 50/50 [==============================] - 115s 2s/step - loss: 2.4238 - accuracy: 0.3113 - val_loss: 2.1303 - val_accuracy: 0.3738
# Epoch 5/100
# 50/50 [==============================] - 106s 2s/step - loss: 1.9778 - accuracy: 0.4112 - val_loss: 1.6246 - val_accuracy: 0.5213
# Epoch 6/100
# 50/50 [==============================] - 108s 2s/step - loss: 1.7561 - accuracy: 0.4669 - val_loss: 1.3094 - val_accuracy: 0.6187
# Epoch 7/100
# 50/50 [==============================] - 114s 2s/step - loss: 1.4912 - accuracy: 0.5406 - val_loss: 1.3520 - val_accuracy: 0.5888
# Epoch 8/100
# 50/50 [==============================] - 56s 1s/step - loss: 1.2902 - accuracy: 0.5968 - val_loss: 1.2341 - val_accuracy: 0.6112
# Epoch 9/100
# 50/50 [==============================] - 35s 705ms/step - loss: 1.1298 - accuracy: 0.6419 - val_loss: 1.1754 - val_accuracy: 0.6350
# Epoch 10/100
# 50/50 [==============================] - 35s 702ms/step - loss: 1.0085 - accuracy: 0.6612 - val_loss: 0.8341 - val_accuracy: 0.7675
# Epoch 11/100
# 50/50 [==============================] - 41s 823ms/step - loss: 0.9108 - accuracy: 0.7050 - val_loss: 0.9401 - val_accuracy: 0.7025
# Epoch 12/100
# 50/50 [==============================] - 42s 844ms/step - loss: 0.8243 - accuracy: 0.7350 - val_loss: 0.6610 - val_accuracy: 0.8213
# Epoch 13/100
# 50/50 [==============================] - 45s 890ms/step - loss: 0.7902 - accuracy: 0.7444 - val_loss: 0.6279 - val_accuracy: 0.8225
# Epoch 14/100
# 50/50 [==============================] - 41s 811ms/step - loss: 0.7370 - accuracy: 0.7613 - val_loss: 0.6433 - val_accuracy: 0.8050
# Epoch 15/100
# 50/50 [==============================] - 41s 828ms/step - loss: 0.6729 - accuracy: 0.7856 - val_loss: 1.3843 - val_accuracy: 0.6250
# Epoch 16/100
# 50/50 [==============================] - 41s 821ms/step - loss: 0.6588 - accuracy: 0.8037 - val_loss: 0.4366 - val_accuracy: 0.8637
# Epoch 17/100
# 50/50 [==============================] - 39s 786ms/step - loss: 0.5899 - accuracy: 0.8181 - val_loss: 0.5360 - val_accuracy: 0.8388
# Epoch 18/100
# 50/50 [==============================] - 39s 789ms/step - loss: 0.6030 - accuracy: 0.8175 - val_loss: 0.5036 - val_accuracy: 0.8475
# Epoch 19/100
# 50/50 [==============================] - 39s 787ms/step - loss: 0.5195 - accuracy: 0.8281 - val_loss: 0.5142 - val_accuracy: 0.8300
# Epoch 20/100
# 50/50 [==============================] - 40s 791ms/step - loss: 0.4917 - accuracy: 0.8456 - val_loss: 0.7239 - val_accuracy: 0.7875
# Epoch 21/100
# 50/50 [==============================] - 37s 747ms/step - loss: 0.4995 - accuracy: 0.8325 - val_loss: 0.4592 - val_accuracy: 0.8600
# Epoch 22/100
# 50/50 [==============================] - 37s 732ms/step - loss: 0.4325 - accuracy: 0.8544 - val_loss: 0.2723 - val_accuracy: 0.9025
# Epoch 23/100
# 50/50 [==============================] - 34s 686ms/step - loss: 0.4935 - accuracy: 0.8456 - val_loss: 0.4935 - val_accuracy: 0.8500
# Epoch 24/100
# 50/50 [==============================] - 37s 746ms/step - loss: 0.4203 - accuracy: 0.8556 - val_loss: 0.4863 - val_accuracy: 0.8475
# Epoch 25/100
# 50/50 [==============================] - 35s 710ms/step - loss: 0.4264 - accuracy: 0.8662 - val_loss: 0.5145 - val_accuracy: 0.8438
# Epoch 26/100
# 50/50 [==============================] - 37s 740ms/step - loss: 0.4024 - accuracy: 0.8744 - val_loss: 0.4447 - val_accuracy: 0.8700
# Epoch 27/100
# 50/50 [==============================] - 38s 763ms/step - loss: 0.3581 - accuracy: 0.8900 - val_loss: 0.3561 - val_accuracy: 0.8813
# Epoch 28/100
# 50/50 [==============================] - 38s 765ms/step - loss: 0.3913 - accuracy: 0.8806 - val_loss: 0.2919 - val_accuracy: 0.9050
# Epoch 29/100
# 50/50 [==============================] - 38s 766ms/step - loss: 0.3225 - accuracy: 0.8963 - val_loss: 0.3773 - val_accuracy: 0.8850
# Epoch 30/100
# 50/50 [==============================] - 40s 801ms/step - loss: 0.3213 - accuracy: 0.8988 - val_loss: 0.4232 - val_accuracy: 0.8925
# Epoch 31/100
# 50/50 [==============================] - 35s 700ms/step - loss: 0.3172 - accuracy: 0.8994 - val_loss: 0.3022 - val_accuracy: 0.9175
# Epoch 32/100
# 50/50 [==============================] - 34s 683ms/step - loss: 0.2949 - accuracy: 0.9044 - val_loss: 0.3841 - val_accuracy: 0.8925
# Epoch 33/100
# 50/50 [==============================] - 35s 700ms/step - loss: 0.3044 - accuracy: 0.9000 - val_loss: 0.4527 - val_accuracy: 0.8763
# Epoch 34/100
# 50/50 [==============================] - 37s 733ms/step - loss: 0.3136 - accuracy: 0.8969 - val_loss: 0.3029 - val_accuracy: 0.9062
# Epoch 35/100
# 50/50 [==============================] - 34s 677ms/step - loss: 0.2692 - accuracy: 0.9175 - val_loss: 0.4181 - val_accuracy: 0.8788
# Epoch 36/100
# 50/50 [==============================] - 32s 648ms/step - loss: 0.2955 - accuracy: 0.9038 - val_loss: 0.2412 - val_accuracy: 0.9112
# Epoch 37/100
# 50/50 [==============================] - 37s 748ms/step - loss: 0.3071 - accuracy: 0.9062 - val_loss: 0.3488 - val_accuracy: 0.9038
# Epoch 38/100
# 50/50 [==============================] - 33s 654ms/step - loss: 0.2315 - accuracy: 0.9237 - val_loss: 0.3009 - val_accuracy: 0.9287
# Epoch 39/100
# 50/50 [==============================] - 37s 738ms/step - loss: 0.2844 - accuracy: 0.9006 - val_loss: 0.2589 - val_accuracy: 0.9287
# Epoch 40/100
# 50/50 [==============================] - 33s 665ms/step - loss: 0.2201 - accuracy: 0.9244 - val_loss: 0.4324 - val_accuracy: 0.8813
# Epoch 41/100
# 50/50 [==============================] - 38s 753ms/step - loss: 0.2097 - accuracy: 0.9219 - val_loss: 0.2742 - val_accuracy: 0.9362
# Epoch 42/100
# 50/50 [==============================] - 34s 686ms/step - loss: 0.2518 - accuracy: 0.9175 - val_loss: 0.3029 - val_accuracy: 0.9112
# Epoch 43/100
# 50/50 [==============================] - 37s 735ms/step - loss: 0.2293 - accuracy: 0.9219 - val_loss: 0.4192 - val_accuracy: 0.8913
# Epoch 44/100
# 50/50 [==============================] - 35s 699ms/step - loss: 0.2458 - accuracy: 0.9225 - val_loss: 0.1919 - val_accuracy: 0.9287
# Epoch 45/100
# 50/50 [==============================] - 36s 714ms/step - loss: 0.2463 - accuracy: 0.9200 - val_loss: 0.3814 - val_accuracy: 0.9013
# Epoch 46/100
# 50/50 [==============================] - 32s 642ms/step - loss: 0.2284 - accuracy: 0.9219 - val_loss: 0.2837 - val_accuracy: 0.9187
# Epoch 47/100
# 50/50 [==============================] - 34s 671ms/step - loss: 0.1770 - accuracy: 0.9394 - val_loss: 0.2833 - val_accuracy: 0.9175
# Epoch 48/100
# 50/50 [==============================] - 32s 648ms/step - loss: 0.2015 - accuracy: 0.9319 - val_loss: 0.3456 - val_accuracy: 0.9250
# Epoch 49/100
# 50/50 [==============================] - 30s 590ms/step - loss: 0.2699 - accuracy: 0.9206 - val_loss: 0.2100 - val_accuracy: 0.9325
# Epoch 50/100
# 50/50 [==============================] - 31s 627ms/step - loss: 0.2385 - accuracy: 0.9244 - val_loss: 0.2727 - val_accuracy: 0.9312
# Epoch 51/100
# 50/50 [==============================] - 29s 581ms/step - loss: 0.2078 - accuracy: 0.9337 - val_loss: 0.1846 - val_accuracy: 0.9550
# Epoch 52/100
# 50/50 [==============================] - 30s 607ms/step - loss: 0.1904 - accuracy: 0.9381 - val_loss: 0.6690 - val_accuracy: 0.8250
# Epoch 53/100
# 50/50 [==============================] - 29s 577ms/step - loss: 0.1977 - accuracy: 0.9331 - val_loss: 0.2579 - val_accuracy: 0.9400
# Epoch 54/100
# 50/50 [==============================] - 30s 609ms/step - loss: 0.2090 - accuracy: 0.9306 - val_loss: 0.2351 - val_accuracy: 0.9362
# Epoch 55/100
# 50/50 [==============================] - 30s 596ms/step - loss: 0.1524 - accuracy: 0.9513 - val_loss: 0.2121 - val_accuracy: 0.9450
# Epoch 56/100
# 50/50 [==============================] - 29s 582ms/step - loss: 0.2071 - accuracy: 0.9350 - val_loss: 0.3240 - val_accuracy: 0.9162
# Epoch 57/100
# 50/50 [==============================] - 31s 621ms/step - loss: 0.1659 - accuracy: 0.9494 - val_loss: 0.3411 - val_accuracy: 0.9050
# Epoch 58/100
# 50/50 [==============================] - 33s 663ms/step - loss: 0.1941 - accuracy: 0.9325 - val_loss: 0.2476 - val_accuracy: 0.9287
# Epoch 59/100
# 50/50 [==============================] - 31s 619ms/step - loss: 0.1487 - accuracy: 0.9519 - val_loss: 0.2123 - val_accuracy: 0.9400
# Epoch 60/100
# 50/50 [==============================] - 29s 575ms/step - loss: 0.1664 - accuracy: 0.9463 - val_loss: 0.3004 - val_accuracy: 0.9275
# Epoch 61/100
# 50/50 [==============================] - 27s 547ms/step - loss: 0.2012 - accuracy: 0.9475 - val_loss: 0.2064 - val_accuracy: 0.9475
# Epoch 62/100
# 50/50 [==============================] - 28s 564ms/step - loss: 0.1815 - accuracy: 0.9469 - val_loss: 0.2867 - val_accuracy: 0.9225
# Epoch 63/100
# 50/50 [==============================] - 28s 568ms/step - loss: 0.1880 - accuracy: 0.9388 - val_loss: 0.2451 - val_accuracy: 0.9225
# Epoch 64/100
# 50/50 [==============================] - 27s 542ms/step - loss: 0.1474 - accuracy: 0.9538 - val_loss: 0.2609 - val_accuracy: 0.9413
# Epoch 65/100
# 50/50 [==============================] - 28s 552ms/step - loss: 0.1655 - accuracy: 0.9438 - val_loss: 0.2007 - val_accuracy: 0.9550
# Epoch 66/100
# 50/50 [==============================] - 27s 545ms/step - loss: 0.1675 - accuracy: 0.9456 - val_loss: 0.2549 - val_accuracy: 0.9337
# Epoch 67/100
# 50/50 [==============================] - 27s 543ms/step - loss: 0.1580 - accuracy: 0.9588 - val_loss: 0.3116 - val_accuracy: 0.9425
# Epoch 68/100
# 50/50 [==============================] - 28s 562ms/step - loss: 0.1892 - accuracy: 0.9431 - val_loss: 0.2689 - val_accuracy: 0.9400
# Epoch 69/100
# 50/50 [==============================] - 26s 529ms/step - loss: 0.1491 - accuracy: 0.9544 - val_loss: 0.4139 - val_accuracy: 0.9038
# Epoch 70/100
# 50/50 [==============================] - 26s 519ms/step - loss: 0.1984 - accuracy: 0.9406 - val_loss: 0.2716 - val_accuracy: 0.9300
# Epoch 71/100
# 50/50 [==============================] - 30s 603ms/step - loss: 0.1639 - accuracy: 0.9538 - val_loss: 0.4659 - val_accuracy: 0.8813
# Epoch 72/100
# 50/50 [==============================] - 26s 515ms/step - loss: 0.1630 - accuracy: 0.9588 - val_loss: 0.2861 - val_accuracy: 0.9300
# Epoch 73/100
# 50/50 [==============================] - 26s 527ms/step - loss: 0.1171 - accuracy: 0.9594 - val_loss: 0.1684 - val_accuracy: 0.9500
# Epoch 74/100
# 50/50 [==============================] - 26s 520ms/step - loss: 0.1344 - accuracy: 0.9550 - val_loss: 0.1425 - val_accuracy: 0.9538
# Epoch 75/100
# 50/50 [==============================] - 26s 513ms/step - loss: 0.1495 - accuracy: 0.9569 - val_loss: 0.1861 - val_accuracy: 0.9400
# Epoch 76/100
# 50/50 [==============================] - 33s 657ms/step - loss: 0.1565 - accuracy: 0.9550 - val_loss: 0.2590 - val_accuracy: 0.9325
# Epoch 77/100
# 50/50 [==============================] - 28s 561ms/step - loss: 0.1579 - accuracy: 0.9519 - val_loss: 0.3845 - val_accuracy: 0.9212
# Epoch 78/100
# 50/50 [==============================] - 26s 517ms/step - loss: 0.1422 - accuracy: 0.9581 - val_loss: 0.2238 - val_accuracy: 0.9513
# Epoch 79/100
# 50/50 [==============================] - 26s 515ms/step - loss: 0.1589 - accuracy: 0.9525 - val_loss: 0.2167 - val_accuracy: 0.9425
# Epoch 80/100
# 50/50 [==============================] - 26s 515ms/step - loss: 0.1499 - accuracy: 0.9531 - val_loss: 0.2448 - val_accuracy: 0.9425
# Epoch 81/100
# 50/50 [==============================] - 26s 520ms/step - loss: 0.1337 - accuracy: 0.9563 - val_loss: 0.1795 - val_accuracy: 0.9450
# Epoch 82/100
# 50/50 [==============================] - 24s 487ms/step - loss: 0.1513 - accuracy: 0.9544 - val_loss: 0.2637 - val_accuracy: 0.9438
# Epoch 83/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.1322 - accuracy: 0.9606 - val_loss: 0.2112 - val_accuracy: 0.9513
# Epoch 84/100
# 50/50 [==============================] - 25s 492ms/step - loss: 0.1001 - accuracy: 0.9700 - val_loss: 0.2405 - val_accuracy: 0.9400
# Epoch 85/100
# 50/50 [==============================] - 25s 500ms/step - loss: 0.1398 - accuracy: 0.9581 - val_loss: 0.2399 - val_accuracy: 0.9388
# Epoch 86/100
# 50/50 [==============================] - 29s 584ms/step - loss: 0.1484 - accuracy: 0.9569 - val_loss: 0.2912 - val_accuracy: 0.9337
# Epoch 87/100
# 50/50 [==============================] - 24s 481ms/step - loss: 0.1250 - accuracy: 0.9631 - val_loss: 0.3151 - val_accuracy: 0.9225
# Epoch 88/100
# 50/50 [==============================] - 27s 543ms/step - loss: 0.1505 - accuracy: 0.9588 - val_loss: 0.2040 - val_accuracy: 0.9550
# Epoch 89/100
# 50/50 [==============================] - 28s 566ms/step - loss: 0.1412 - accuracy: 0.9644 - val_loss: 0.1893 - val_accuracy: 0.9588
# Epoch 90/100
# 50/50 [==============================] - 27s 537ms/step - loss: 0.1645 - accuracy: 0.9625 - val_loss: 0.2335 - val_accuracy: 0.9475
# Epoch 91/100
# 50/50 [==============================] - 28s 564ms/step - loss: 0.1645 - accuracy: 0.9606 - val_loss: 0.4122 - val_accuracy: 0.9150
# Epoch 92/100
# 50/50 [==============================] - 23s 455ms/step - loss: 0.1182 - accuracy: 0.9694 - val_loss: 0.3440 - val_accuracy: 0.9237
# Epoch 93/100
# 50/50 [==============================] - 24s 475ms/step - loss: 0.1394 - accuracy: 0.9575 - val_loss: 0.6730 - val_accuracy: 0.8500
# Epoch 94/100
# 50/50 [==============================] - 21s 430ms/step - loss: 0.1748 - accuracy: 0.9581 - val_loss: 0.1638 - val_accuracy: 0.9550
# Epoch 95/100
# 50/50 [==============================] - 23s 457ms/step - loss: 0.1449 - accuracy: 0.9638 - val_loss: 0.2623 - val_accuracy: 0.9513
# Epoch 96/100
# 50/50 [==============================] - 21s 422ms/step - loss: 0.0959 - accuracy: 0.9725 - val_loss: 0.2682 - val_accuracy: 0.9325
# Epoch 97/100
# 50/50 [==============================] - 20s 405ms/step - loss: 0.1321 - accuracy: 0.9581 - val_loss: 0.2001 - val_accuracy: 0.9513
# Epoch 98/100
# 50/50 [==============================] - 20s 409ms/step - loss: 0.1285 - accuracy: 0.9625 - val_loss: 0.1585 - val_accuracy: 0.9538
# Epoch 99/100
# 50/50 [==============================] - 21s 429ms/step - loss: 0.0989 - accuracy: 0.9750 - val_loss: 0.2829 - val_accuracy: 0.9450
# Epoch 100/100
# 50/50 [==============================] - 19s 383ms/step - loss: 0.1498 - accuracy: 0.9600 - val_loss: 0.1853 - val_accuracy: 0.9675

# %%
## Model save
model.save_weights("deneme.h5")

## Model evaluation
print(hist.history.keys())
plt.plot(hist.history["loss"], label = "Train Loss")
plt.plot(hist.history["val_loss"], label = "Validation Loss")
plt.legend()
plt.show()
plt.figure()
plt.plot(hist.history["accuracy"], label = "Train acc")
plt.plot(hist.history["val_accuracy"], label = "Validation acc")
plt.legend()
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
## Save history
import json
with open("deneme.json", "w") as f:
    json.dump(hist.history, f)

# %%
import codecs
with codecs.open("deneme.json", "r", encoding = "utf-8") as f:
    h = json.loads(f.read())

plt.plot(h["loss"], label = "Train Loss")
plt.plot(h["val_loss"], label = "Validation Loss")
plt.legend()
plt.show()
plt.figure()
plt.plot(h["accuracy"], label = "Train acc")
plt.plot(h["val_accuracy"], label = "Validation acc")
plt.legend()
plt.show()

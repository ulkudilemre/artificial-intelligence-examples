# %%
for i, j in list(range(3), range(5)):
    print("x: ", i, "y: ", j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12492/750637069.py in <module>
# ----> 1 for i, j in list(range(3), range(5)):
#       2     print("x: ", i, "y: ", j)
#
# TypeError: list expected at most 1 argument, got 2
